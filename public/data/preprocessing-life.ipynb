# %%
import csv

file_path = 'life-expectancy.csv'

import pandas as pd

# %%
# Import pandas
import pandas as pd

# reading csv file 
data = pd.read_csv("life-expectancy.csv")
print(df.head())
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                             Indicator Name  Indicator Code       1960  \
# 0  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  64.152000
# 1  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  44.085552
# 2  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  32.535000
# 3  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  37.845152
# 4  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  38.211000
#
#         1961       1962       1963       1964       1965  ...       2014  \
# 0  64.537000  64.752000  65.132000  65.294000  65.502000  ...  75.601000
# 1  44.386697  44.752182  44.913159  45.479043  45.498338  ...  61.337917
# ...

# %%
import pandas as pd

# Assuming 'data' is your DataFrame with countries in rows and years in columns

# Melt the DataFrame to transform years into rows for each country
melted_data = pd.melt(data, id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'],
                      var_name='Year', value_name='Life Expectancy')

# Display the first few rows of the melted DataFrame
melted_data.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                             Indicator Name  Indicator Code  Year  \
# 0  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1960
# 1  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1960
# 2  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1960
# 3  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1960
# 4  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1960
#
#    Life Expectancy
# 0        64.152000
# 1        44.085552
# 2        32.535000
# 3        37.845152
# 4        38.211000

# %%
# Define the output file name
output_file = 'life-expectancy_modified.csv'
melted_data.to_csv(output_file, index=False)
